# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.random.random_integers(low=0, high=10, size=100)
# Out:
# /tmp/ipykernel_36539/1723107253.py:1: DeprecationWarning: This function is deprecated. Please call randint(0, 10 + 1) instead
#   data = np.random.random_integers(low=0, high=10, size=100)

# %%
plt.hist(data)
plt.xlabel('Value')
plt.ylabel('Appearance')
# Out:
# Text(0, 0.5, 'Appearance')

# %%
normal_ints = (np.random.randn(90000) * 1500).astype(dtype=np.int32)
plt.hist(normal_ints)
# Out:
# (array([2.0000e+00, 1.2300e+02, 1.4860e+03, 8.7550e+03, 2.3829e+04,
#         3.1056e+04, 1.8809e+04, 5.2070e+03, 6.9900e+02, 3.4000e+01]),
#  array([-7222., -5869., -4516., -3163., -1810.,  -457.,   896.,  2249.,
#          3602.,  4955.,  6308.]),
#  <BarContainer object of 10 artists>)
